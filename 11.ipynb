# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("Cat vs Dog (Small Data set)")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# ...

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = "C:/Users/Dell/Desktop/pac/Quater 3/Practice/data_directories/test/cats/cat.1502.jpg"

img_path = image.load_img(img , target_size = (150,150,3))
img_tensor = image.img_to_array(img_path)
img_tensor = np.expand_dims(img_tensor , axis = 0)
img_tensor = img_tensor/255.

# %%
from matplotlib import pyplot as plt

img1 = "C:/Users/Dell/Desktop/pac/Quater 3/Practice/data_directories/test/cats/cat.1502.jpg"

img_tensor1 = plt.imread(img1)
print(img_tensor1 .shape)
img_tensor1 = np.reshape(img_tensor1 , (1,479,400,3))
# Out:
# (479, 400, 3)

# %%
img_plot = plt.imshow(img_tensor[0])

# %%
img_plot1 = plt.imshow(img_tensor1[0])

# %%
from tensorflow.keras import models

layers_output = [layers.output for layers in model.layers[:3]]
activation_model = models.Model(inputs = model.input , outputs = layers_output)

# %%
activation = activation_model.predict(img_tensor)

# %%
first_layer_activation = activation[0]

# %%
plt.matshow(first_layer_activation[0, :, :, 31] , cmap='viridis')

# %%
plt.imshow(first_layer_activation[0,:,:,4])

# %%
second_layer_activation = activation[3]

plt.imshow(second_layer_activation[0,:,:,3])
